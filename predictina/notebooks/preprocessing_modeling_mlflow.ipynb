# %% [markdown]
# # Predictina — Week 3 Modeling + MLflow
# This notebook delegates production logic to `src/` modules and tracks runs in MLflow.

# %%
# %pip install -r ../requirements.txt

# %%
import os
os.environ['MLFLOW_TRACKING_URI']='file:../mlruns'

# %%
import sys
sys.path.append('../src')
from train import run_training

# %%
run_training(
    data_path='../data/house_pricing_raw.csv',
    experiment_name='predictina-house-prices',
    model_name='PredictinaHousePriceModel'
)

# %% [markdown]
# ## Visualize experiments
# Run in terminal: `mlflow ui --backend-store-uri ../mlruns --port 5000`.
